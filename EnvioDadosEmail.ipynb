# %%
import pyautogui
import time
import pyperclip

pyautogui.alert("Programa irá se inciar, não mexa no teclaro!")    # envia alerta 
pyautogui.hotkey("ctrl", "t")   # abre aba nova 
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyperclip.copy(link)       # copia no buscador 
pyautogui.hotkey("ctrl", "v")   
pyautogui.press("enter")       # pressiona tecla enter
time.sleep(5)
pyautogui.click(412, 372, clicks=2)      # clica 2 vezes na coordenada especificadad
time.sleep(5)
pyautogui.click(474, 558)    # clica 1 vez na coordenada especificada
pyautogui.click(1668, 237)
time.sleep(2)
pyautogui.click(1473, 690, clicks=2)
time.sleep(10)

import pandas as pd

tabela = pd.read_excel(r'D:\Download\Vendas - Dez.xlsx')      # atribui arquivo excel a variavel tabela 
display(tabela)      # mostra tabela 

faturamento = tabela['Valor Final'].sum()        # soma todos valores da coluna "ValorFinal" e atribui a variável faturamento
qtdP = tabela['Quantidade'].sum()     # soma todos valores da coluna "Quantidade" e atribui a variável qtdP
 
time.sleep(10)

pyautogui.hotkey("ctrl", "t")        
email = "https://mail.google.com/mail/u/0/#inbox"
pyperclip.copy(email)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)
pyautogui.click(100, 254)
time.sleep(3)

pyautogui.write("enzo@maneira.com")
pyautogui.press('tab')
pyautogui.press('tab')

time.sleep(3)
pyautogui.write("teste")
pyautogui.press('tab')

texto = f"""
Boa noite Enzo

Ontem o faturamento foi de: R${faturamento:,.2f}
e a quantidade de produtos foi: {qtdP:,}

boa boa fé p td, Enzo
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
time.sleep(3)
pyautogui.hotkey('ctrl', 'enter')
pyautogui.alert("Você já tem o controle do seu computador novamente")
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1500, y=566)

# %%
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...
